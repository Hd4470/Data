# %%
"""
data1 <- read.csv("SNS_Dataset.csv")
table(data1$gender)
table(data1$gender, useNA = "ifany")
summary(data1$age)
data1$age <- ifelse(data1$age >= 13 & data1$age < 20,data1$age, NA)
summary(data1$age)
ave_age <- ave(data1$age, data1$gradyear, FUN =function(x) mean(x, na.rm = TRUE))
data1$age <- ifelse(is.na(data1$age), ave_age, data1$age) 
summary(data1$age)
interests <- data1[5:38]
interests_z <- as.data.frame(lapply(interests, scale))
head(interests_z,3)
set.seed(10000)
model1 <- kmeans(interests_z, 5)
model1$size
data2= cbind(data1, cluster=model1$cluster)

wss <- sapply(1:k.max,  function(k){set.seed(10000); kmeans(interests_z, k)$tot.withinss})
plot(wss)



"""

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/Users/harsha/Downloads/SNS_Dataset.csv',index_col=0)

# %%
df=df.dropna()
df.head()
# Out:
#          gender     age  friends  basketball  football  soccer  softball  \
# gradyear
# 2006          M  18.982        7           0         0       0         0
# 2006          F  18.801        0           0         1       0         0
# 2006          M  18.335       69           0         1       0         0
# 2006          F  18.875        0           0         0       0         0
# 2006          F  18.930       72           0         0       0         0
#
#           volleyball  swimming  cheerleading  ...    blonde  mall  shopping  \
# gradyear                                      ...
# 2006               0         0             0  ...         0     0         0
# 2006               0         0             0  ...         0     1         0
# 2006               0         0             0  ...         0     0         0
# 2006               0         0             0  ...         0     0         0
# 2006               0         0             0  ...         0     2         0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24005 entries, 2006 to 2009
# Data columns (total 37 columns):
# gender          24005 non-null object
# age             24005 non-null float64
# friends         24005 non-null int64
# basketball      24005 non-null int64
# football        24005 non-null int64
# soccer          24005 non-null int64
# softball        24005 non-null int64
# volleyball      24005 non-null int64
# swimming        24005 non-null int64
# cheerleading    24005 non-null int64
# baseball        24005 non-null int64
# tennis          24005 non-null int64
# sports          24005 non-null int64
# cute            24005 non-null int64
# hot             24005 non-null int64
# kissed          24005 non-null int64
# dance           24005 non-null int64
# band            24005 non-null int64
# marching        24005 non-null int64
# music           24005 non-null int64
# rock            24005 non-null int64
# god             24005 non-null int64
# ...

# %%
df.describe()
# Out:
#                 age       friends    basketball      football        soccer  \
# count  24005.000000  24005.000000  24005.000000  24005.000000  24005.000000
# mean      17.951418     30.760966      0.276526      0.266236      0.227911
# std        7.625351     36.368500      0.814345      0.720804      0.928364
# min        3.086000      0.000000      0.000000      0.000000      0.000000
# 25%       16.309000      4.000000      0.000000      0.000000      0.000000
# 50%       17.287000     21.000000      0.000000      0.000000      0.000000
# 75%       18.259000     44.000000      0.000000      0.000000      0.000000
# max      106.927000    830.000000     24.000000     15.000000     27.000000
#
#            softball    volleyball      swimming  cheerleading      baseball  \
# count  24005.000000  24005.000000  24005.000000  24005.000000  24005.000000
# mean       0.167548      0.146178      0.136888      0.108311      0.112727
# ...

# %%
#encode gender
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
df["gender_code"] = lb_make.fit_transform(df["gender"])
df[["gender", "gender_code"]].head()
df=df.drop('gender',axis=1)
df.head()
# Out:
#              age  friends  basketball  football  soccer  softball  volleyball  \
# gradyear
# 2006      18.982        7           0         0       0         0           0
# 2006      18.801        0           0         1       0         0           0
# 2006      18.335       69           0         1       0         0           0
# 2006      18.875        0           0         0       0         0           0
# 2006      18.930       72           0         0       0         0           0
#
#           swimming  cheerleading  baseball     ...       mall  shopping  \
# gradyear                                       ...
# 2006             0             0         0     ...          0         0
# 2006             0             0         0     ...          1         0
# 2006             0             0         0     ...          0         0
# 2006             0             0         0     ...          0         0
# 2006             0             0         0     ...          2         0
#
# ...

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=5)

# %%
kmeans.fit(df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[  1.81294770e+01,   6.49381994e+00,   2.39017872e-01,
#           2.45699015e-01,   1.99682646e-01,   1.30449307e-01,
#           1.16001336e-01,   1.18256222e-01,   8.78570236e-02,
#           9.91314515e-02,   8.15934525e-02,   1.35877735e-01,
#           2.83948555e-01,   1.12159679e-01,   9.82127944e-02,
#           3.78236178e-01,   2.85952898e-01,   3.69133122e-02,
#           7.16886588e-01,   2.32086187e-01,   4.26173376e-01,
#           2.18473359e-01,   9.41205946e-02,   1.92917989e-02,
#           4.15233005e-01,   1.01302823e-01,   8.51010523e-02,
#           2.33589444e-01,   3.06163354e-01,   1.38216135e-01,
#           5.56205111e-02,   4.16736262e-02,   1.82395190e-01,
#           1.05645565e-01,   9.02789377e-02,   6.99849674e-02,
#           2.20394187e-01,   3.33066907e-13],
#        [  1.77075654e+01,   1.27669087e+02,   3.93153527e-01,
#           2.98755187e-01,   2.71784232e-01,   2.58298755e-01,
# ...

# %%
df["Cluster"]= x
df.head()
# Out:
#              age  friends  basketball  football  soccer  softball  volleyball  \
# gradyear
# 2006      18.982        7           0         0       0         0           0
# 2006      18.801        0           0         1       0         0           0
# 2006      18.335       69           0         1       0         0           0
# 2006      18.875        0           0         0       0         0           0
# 2006      18.930       72           0         0       0         0           0
#
#           swimming  cheerleading  baseball   ...     shopping  clothes  \
# gradyear                                     ...
# 2006             0             0         0   ...            0        0
# 2006             0             0         0   ...            0        0
# 2006             0             0         0   ...            0        0
# 2006             0             0         0   ...            0        0
# 2006             0             0         0   ...            0        0
#
# ...
