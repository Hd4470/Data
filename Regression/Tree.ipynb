# %%
"""train1=read.csv("train_hr100.csv")
test1=read.csv("test_hr100.csv")
model1= rpart(job_change ~ ., train1,  method = "class")
pred1 <- predict(model1, test1, type = "class")
table(test1$left, pred1)
fancyRpartPlot(model1)"""
# Out:
# 'train1=read.csv("train_hr100.csv")\ntest1=read.csv("test_hr100.csv")\nmodel1= rpart(job_change ~ ., train1,  method = "class")\npred1 <- predict(model1, test1, type = "class")\ntable(test1$left, pred1)\nfancyRpartPlot(model1)'

# %%
import pandas as pd

#Read the data 
df = pd.read_csv('/Users/harsha/Desktop/dt.csv')

from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
#encode sales
df["sales_code"] = lb_make.fit_transform(df["sales"])
df[["sales", "sales_code"]].head()
# Out:
#        sales  sales_code
# 0    support           8
# 1  marketing           5
# 2    support           8
# 3         hr           3
# 4  technical           9

# %%
#encode salary 
df["salary_code"] = lb_make.fit_transform(df["salary"])
df[["salary", "salary_code"]].head()
df1=df.drop('sales', axis=1)
df2=df1.drop('salary', axis=1)
df2.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.98             0.53               4                   166
# 1                0.48             0.51               3                   136
# 2                0.84             0.50               3                   227
# 3                0.73             0.98               3                   227
# 4                0.10             0.92               6                   258
#
#    time_spend_company  Work_accident  job_change  promotion_last_5years  \
# 0                   2              0           0                      0
# 1                   3              0           0                      0
# 2                   2              0           0                      0
# 3                   2              1           0                      0
# 4                   4              0           1                      0
#
#    sales_code  salary_code
# 0           8            2
# ...

# %%
#EDA
x=df.print(classification_report(y_test,predictions))['satisfaction_level']
ax = sns.distplot(x)
# Out:
#   File "<ipython-input-5-425afafa0de5>", line 2
#     x=df.print(classification_report(y_test,predictions))['satisfaction_level']
#              ^
# SyntaxError: invalid syntax

# %%
from sklearn.model_selection import train_test_split

X = df2.drop('job_change',axis=1)
y = df2['job_change']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#predict on sample data

test=X[4:5]
predictions = dtree.predict(test)
predictions
# Out:
# array([1])

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print classification_report(y_test,predictions)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      0.98      0.98      2397
#           1       0.94      0.95      0.95       753
#
# avg / total       0.97      0.97      0.97      3150

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[2349   48]
#  [  34  719]]

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydot 

features = df2.drop('job_change',axis=1)
features
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.98             0.53               4
# 1                    0.48             0.51               3
# 2                    0.84             0.50               3
# 3                    0.73             0.98               3
# 4                    0.10             0.92               6
# 5                    0.40             0.52               2
# 6                    0.09             0.82               6
# 7                    0.58             0.79               5
# 8                    0.58             1.00               4
# 9                    0.21             0.99               6
# 10                   0.30             0.67               3
# 11                   0.10             0.81               7
# 12                   0.98             0.54               4
# 13                   0.66             0.53               4
# 14                   0.70             0.60               3
# ...

# %%
dot_data = StringIO()  
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png())
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-18-0f7874105d5a> in <module>()
#       1 dot_data = StringIO()
# ----> 2 export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)
#       3
#       4 graph = pydot.graph_from_dot_data(dot_data.getvalue())
#       5 Image(graph[0].create_png())
#
# /Users/harsha/anaconda2/lib/python2.7/site-packages/sklearn/tree/export.pyc in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision)
#     427                                  "does not match number of features, %d"
#     428                                  % (len(feature_names),
# --> 429                                     decision_tree.n_features_))
#     430
#     431         # The depth of each node for plotting with 'leaf' option
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)
print confusion_matrix(y_test,rfc_pred)
# Out:
# [[2391    6]
#  [  31  722]]

# %%
print classification_report(y_test,rfc_pred)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      2397
#           1       0.99      0.96      0.98       753
#
# avg / total       0.99      0.99      0.99      3150
